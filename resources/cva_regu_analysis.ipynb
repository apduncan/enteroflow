# %% [markdown]
# # BiCV Rank Selection

# %%
from cvanmf import denovo
import pickle
import plotnine as p9

# %%
with open("regu_combined.pickle", "rb") as f:
    rank_res = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 with open("regu_combined.pickle", "rb") as f:
#       2     rank_res = pickle.load(f)
#
# File ~/mambaforge/envs/enteroflow/lib/python3.12/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'regu_combined.pickle'

# %%
fig = denovo.plot_regu_selection(rank_res, jitter=False, n_col=2) + p9.theme(figure_size=(9, 6))
fig
# Out:
# <Figure Size: (900 x 600)>

# %% [markdown]
# ## Suggested optimal alpha

# %%
denovo.suggest_alpha(rank_res)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 denovo.suggest_alpha(rank_res)
#
# NameError: name 'rank_res' is not defined

# %% [markdown]
# ## Write table

# %%
denovo.BicvResult.results_to_table(rank_res).to_csv('regu_analysis.tsv', sep="\t")
