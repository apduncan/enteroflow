# %% [markdown]
# # Analysis of NMF bicv for enterosignature rank choice

# %%
from cvanmf import denovo
import pickle
import plotnine as p9

# %%
with open("rank_combined.pickle", "rb") as f:
    rank_res = pickle.load(f)

# %%
fig = denovo.plot_rank_selection(rank_res) + p9.theme(figure_size=(12, 6))
fig
# Out:
# <Figure Size: (1200 x 600)>

# %%
denovo.BicvResult.results_to_table(rank_res).to_csv('rank_analysis.tsv', sep="\t")
